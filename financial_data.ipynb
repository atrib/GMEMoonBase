# %%
import yfinance as yf

#define the ticker symbol
tickerSymbol = 'GME'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2019-1-1', end='2021-3-11')

#see your data
tickerDf
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2018-12-31   11.925388   12.254231   11.906045   12.205872   2790300
# 2019-01-02   12.041450   12.747496   12.012435   12.641105   2124200
# 2019-01-03   12.554058   12.824870   12.273574   12.544387   1750400
# 2019-01-04   13.569602   14.788255   13.250431   14.739896  11915700
# 2019-01-07   14.614162   15.291192   14.449740   14.972020   4718000
# ...                ...         ...         ...         ...       ...
# 2021-03-04  125.000000  147.869995  115.300003  132.350006  32473600
# 2021-03-05  128.169998  151.529999  127.500000  137.740005  30660200
# 2021-03-08  154.889999  210.869995  146.100006  194.500000  63424800
# 2021-03-09  217.710007  249.850006  208.509995  246.899994  38725800
# 2021-03-10  269.429993  348.500000  172.000000  265.000000  71361900
#
#             Dividends  Stock Splits
# Date
# 2018-12-31        0.0             0
# 2019-01-02        0.0             0
# 2019-01-03        0.0             0
# 2019-01-04        0.0             0
# 2019-01-07        0.0             0
# ...               ...           ...
# 2021-03-04        0.0             0
# 2021-03-05        0.0             0
# 2021-03-08        0.0             0
# 2021-03-09        0.0             0
# 2021-03-10        0.0             0
#
# [552 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

tickerDf['median_daily'] = (tickerDf.High+tickerDf.Low)/2
print(type(tickerDf.index))

plt.figure(figsize=(20,10))
plt.title('Game Stop')
plt.plot(tickerDf.index, tickerDf['median_daily'])
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
